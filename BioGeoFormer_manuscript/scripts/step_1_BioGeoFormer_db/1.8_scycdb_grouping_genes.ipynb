# %%
gene_list_all = ["cysC", "cysND", "cysH", "cysIJ", "cysNC", "cysQ", "nrnA", "sat", "sir", "aprAB", "dsrAB", 
                 "dsrC", "dsrDNT", "dsrEFH", "dsrL", "dsrMKJOP", "qmoABC", "rdsr", "sat", "asrABC", "fsr", 
                 "hydABDG", "mccA", "otr", "psrABC", "rdlA", "shyABCD", "sreABC", "sudAB", "ttrABC", "soxAX",
                 "soxB", "soxCD", "soxYZ", "doxAD", "fccAB", "glpE", "soeABC", "sorAB", "sqr", "sseA", "tsdAB",
                 "phsABC", "tetH", "sor", "acuI", "acuNK", "betAB", "betC", "comABCDE", "dddAC", "dddDKLPQWY",
                 "dddT", "ddhABC", "dmdABCD", "dmoA", "dmsABC", "dsyB", "gdh", "hpsN", "hpsOP", "iseJ", "isfD",
                 "mddA", "mdh", "mtsAB", "prpE", "pta", "sfnG", "slcCD", "sqdBDX", "tauXY", "tmm", "toa", "tpa", 
                 "yihQ", "cuyA", "cysEKMO", "hdrABCDE", "mccB", "metABCXYZ", "msmAB", "mtoX", "ssuDE", "suyAB",
                 "tauD", "tbuBC", "tmoCF", "touCF", "xsc", "cuyZ", "cysAPUWZ", "hpsKLM", "iseKLM", "sbp", "sgpABC", 
                 "soxL", "ssuABC", "sulP", "tauABC", "tauE", "tauZ", "tusA", "tusBCDE"
            ]

unique_strings = []

for string in gene_list_all: 
    if string not in unique_strings: 
        unique_strings.append(string)
    else: 
        print("this string is a dup!:" + string)
# Out:
# this string is a dup!:sat

# %%
# assimilatory sulphate reduction

# %%
gene_list = ["cysC", "cysND", "cysH", "cysIJ", "cysNC", "cysQ", "nrnA", "sat", "sir"]

asssulred = []
cycle_dict = {}

for gene in gene_list: 
    if len(gene) <= 3: 
        asssulred.append(gene)

for gene in gene_list: 
  for i in gene[3:]:
    if i.isalpha(): 
      asssulred.append(gene[0:3] + i)
    else: 
      asssulred[-1] = asssulred[-1] + i
    
cycle_dict["asssulred"] = asssulred
    
print(asssulred)
# Out:
# ['sat', 'sir', 'cysC', 'cysN', 'cysD', 'cysH', 'cysI', 'cysJ', 'cysN', 'cysC', 'cysQ', 'nrnA']

# %%
# dissimilatory sulphur reduction and oxidation

# %%
gene_list = ["aprAB", "dsrAB", "dsrC", "dsrDNT", "dsrEFH", "dsrL", "dsrMKJOP", "qmoABC", "rdsr", "sat"]

dsro = []

for gene in gene_list: 
    if len(gene) <= 3: 
        dsro.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              dsro.append(gene[0:3] + i)
            else: 
              dsro[-1] = dsro[-1] + i
print(dsro)
cycle_dict["dsro"] = dsro
print(cycle_dict)
# Out:
# ['aprA', 'aprB', 'dsrA', 'dsrB', 'dsrC', 'dsrD', 'dsrN', 'dsrT', 'dsrE', 'dsrF', 'dsrH', 'dsrL', 'dsrM', 'dsrK', 'dsrJ', 'dsrO', 'dsrP', 'qmoA', 'qmoB', 'qmoC', 'rdsr', 'sat']
# {'asssulred': ['sat', 'sir', 'cysC', 'cysN', 'cysD', 'cysH', 'cysI', 'cysJ', 'cysN', 'cysC', 'cysQ', 'nrnA'], 'dsro': ['aprA', 'aprB', 'dsrA', 'dsrB', 'dsrC', 'dsrD', 'dsrN', 'dsrT', 'dsrE', 'dsrF', 'dsrH', 'dsrL', 'dsrM', 'dsrK', 'dsrJ', 'dsrO', 'dsrP', 'qmoA', 'qmoB', 'qmoC', 'rdsr', 'sat']}

# %%
#sulphur reduction

# %%
gene_list = ["asrABC", "fsr", "hydABDG", "mccA", "otr", 
             "psrABC", "rdlA", "shyABCD", "sreABC", "sudAB", "ttrABC"]

sulred = []

for gene in gene_list: 
    if len(gene) <= 3: 
        sulred.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              sulred.append(gene[0:3] + i)
            else: 
              sulred[-1] = sulred[-1] + i
print(sulred)
cycle_dict["sulred"] = sulred
# Out:
# ['asrA', 'asrB', 'asrC', 'fsr', 'hydA', 'hydB', 'hydD', 'hydG', 'mccA', 'otr', 'psrA', 'psrB', 'psrC', 'rdlA', 'shyA', 'shyB', 'shyC', 'shyD', 'sreA', 'sreB', 'sreC', 'sudA', 'sudB', 'ttrA', 'ttrB', 'ttrC']

# %%
# SOX systems

# %%
gene_list = ["soxAX", "soxB", "soxCD", "soxYZ"]

SOX = []

for gene in gene_list: 
    if len(gene) <= 3: 
        SOX.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              SOX.append(gene[0:3] + i)
            else: 
              SOX[-1] = SOX[-1] + i
print(SOX)
cycle_dict["SOX"] = SOX
# Out:
# ['soxA', 'soxX', 'soxB', 'soxC', 'soxD', 'soxY', 'soxZ']

# %%
#Sulphur oxidation

# %%
gene_list = ["doxAD", "fccAB", "glpE", "soeABC", "sorAB", "sqr", "sseA", "tsdAB"]

sulfur_ox = []

for gene in gene_list: 
    if len(gene) <= 3: 
        sulfur_ox.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              sulfur_ox.append(gene[0:3] + i)
            else: 
              sulfur_ox[-1] = sulfur_ox[-1] + i
print(sulfur_ox)
cycle_dict["sulfur_ox"] = sulfur_ox
# Out:
# ['doxA', 'doxD', 'fccA', 'fccB', 'glpE', 'soeA', 'soeB', 'soeC', 'sorA', 'sorB', 'sqr', 'sseA', 'tsdA', 'tsdB']

# %%
#Sulphur disproportionation

# %%
gene_list = ["phsABC", "tetH", "sor"]

sulfur_dis = []

for gene in gene_list: 
    if len(gene) <= 3: 
        sulfur_dis.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              sulfur_dis.append(gene[0:3] + i)
            else: 
              sulfur_dis[-1] = sulfur_dis[-1] + i
print(sulfur_dis)
cycle_dict["sulfur_dis"] = sulfur_dis
# Out:
# ['phsA', 'phsB', 'phsC', 'tetH', 'sor']

# %%
#Organic sulphur transformation

# %%
gene_list = ["acuI", "acuNK", "betAB", "betC", "comABCDE", "dddAC", "dddDKLPQWY",
                 "dddT", "ddhABC", "dmdABCD", "dmoA", "dmsABC", "dsyB", "gdh", "hpsN", "hpsOP", "iseJ", "isfD",
                 "mddA", "mdh", "mtsAB", "prpE", "pta", "sfnG", "slcCD", "sqdBDX", "tauXY", "tmm", "toa", "tpa", 
                 "yihQ"]

org_sul_trans = []

for gene in gene_list: 
    if len(gene) <= 3: 
        org_sul_trans.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              org_sul_trans.append(gene[0:3] + i)
            else: 
              org_sul_trans[-1] = org_sul_trans[-1] + i
print(org_sul_trans)
cycle_dict["org_sul_trans"] = org_sul_trans
# Out:
# ['acuI', 'acuN', 'acuK', 'betA', 'betB', 'betC', 'comA', 'comB', 'comC', 'comD', 'comE', 'dddA', 'dddC', 'dddD', 'dddK', 'dddL', 'dddP', 'dddQ', 'dddW', 'dddY', 'dddT', 'ddhA', 'ddhB', 'ddhC', 'dmdA', 'dmdB', 'dmdC', 'dmdD', 'dmoA', 'dmsA', 'dmsB', 'dmsC', 'dsyB', 'gdh', 'hpsN', 'hpsO', 'hpsP', 'iseJ', 'isfD', 'mddA', 'mdh', 'mtsA', 'mtsB', 'prpE', 'pta', 'sfnG', 'slcC', 'slcD', 'sqdB', 'sqdD', 'sqdX', 'tauX', 'tauY', 'tmm', 'toa', 'tpa', 'yihQ']

# %%
#Linkages between inorganic and organic sulphur transformation

# %%
gene_list = ["cuyA", "cysEKMO", "hdrABCDE", "mccB", "metABCXYZ", "msmAB", "mtoX", "ssuDE", "suyAB",
                 "tauD", "tbuBC", "tmoCF", "touCF", "xsc"]

in_or_sul = []

for gene in gene_list: 
    if len(gene) <= 3: 
        in_or_sul.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              in_or_sul.append(gene[0:3] + i)
            else: 
              in_or_sul[-1] = in_or_sul[-1] + i
print(in_or_sul)
cycle_dict["in_or_sul"] = in_or_sul
# Out:
# ['cuyA', 'cysE', 'cysK', 'cysM', 'cysO', 'hdrA', 'hdrB', 'hdrC', 'hdrD', 'hdrE', 'mccB', 'metA', 'metB', 'metC', 'metX', 'metY', 'metZ', 'msmA', 'msmB', 'mtoX', 'ssuD', 'ssuE', 'suyA', 'suyB', 'tauD', 'tbuB', 'tbuC', 'tmoC', 'tmoF', 'touC', 'touF', 'xsc']

# %%
#sulphur other

# %%
gene_list = ["cuyZ", "cysAPUWZ", "hpsKLM", "iseKLM", "sbp", "sgpABC", 
                 "soxL", "ssuABC", "sulP", "tauABC", "tauE", "tauZ", "tusA", "tusBCDE"]

sul_other = []

for gene in gene_list: 
    if len(gene) <= 3: 
        sul_other.append(gene)
    else: 
        for i in gene[3:]:
            if i.isalpha(): 
              sul_other.append(gene[0:3] + i)
            else: 
              sul_other[-1] = sul_other[-1] + i
print(sul_other)
cycle_dict["sul_other"] = sul_other
# Out:
# ['cuyZ', 'cysA', 'cysP', 'cysU', 'cysW', 'cysZ', 'hpsK', 'hpsL', 'hpsM', 'iseK', 'iseL', 'iseM', 'sbp', 'sgpA', 'sgpB', 'sgpC', 'soxL', 'ssuA', 'ssuB', 'ssuC', 'sulP', 'tauA', 'tauB', 'tauC', 'tauE', 'tauZ', 'tusA', 'tusB', 'tusC', 'tusD', 'tusE']

# %%
for value in cycle_dict: 
    print(value)
    for value2 in cycle_dict[value]: 
        print(value2)
# Out:
# asssulred
# sat
# sir
# cysC
# cysN
# cysD
# cysH
# cysI
# cysJ
# cysN
# cysC
# cysQ
# nrnA
# dsro
# aprA
# aprB
# dsrA
# dsrB
# dsrC
# dsrD
# dsrN
# dsrT
# dsrE
# dsrF
# dsrH
# dsrL
# dsrM
# dsrK
# dsrJ
# dsrO
# dsrP
# qmoA
# qmoB
# qmoC
# rdsr
# sat
# sulred
# asrA
# asrB
# asrC
# fsr
# hydA
# hydB
# hydD
# hydG
# mccA
# otr
# psrA
# psrB
# psrC
# rdlA
# shyA
# shyB
# shyC
# shyD
# sreA
# sreB
# sreC
# sudA
# sudB
# ttrA
# ttrB
# ttrC
# SOX
# soxA
# soxX
# soxB
# soxC
# soxD
# soxY
# soxZ
# sulfur_ox
# doxA
# doxD
# fccA
# fccB
# glpE
# soeA
# soeB
# soeC
# sorA
# sorB
# sqr
# sseA
# tsdA
# tsdB
# sulfur_dis
# phsA
# phsB
# phsC
# tetH
# sor
# org_sul_trans
# acuI
# acuN
# acuK
# betA
# betB
# betC
# comA
# comB
# comC
# comD
# comE
# dddA
# dddC
# dddD
# dddK
# dddL
# dddP
# dddQ
# dddW
# dddY
# dddT
# ddhA
# ddhB
# ddhC
# dmdA
# dmdB
# dmdC
# dmdD
# dmoA
# dmsA
# dmsB
# dmsC
# dsyB
# gdh
# hpsN
# hpsO
# hpsP
# iseJ
# isfD
# mddA
# mdh
# mtsA
# mtsB
# prpE
# pta
# sfnG
# slcC
# ...

# %%
import os
from pathlib import Path

# Get the current notebook's directory
notebook_dir = Path(os.getcwd())


output_dir = notebook_dir / 'cycle_dicts'
output_dir.mkdir(exist_ok=True)  # create folder if it doesn’t exist

# Write your files
with open(output_dir / '../../../cycle_dicts/cycle_dict_scyc.txt', 'w') as f:
    print(cycle_dict, file=f)

import json
with open(output_dir / '../../../cycle_dicts/cycle_dict_scyc.json', 'w') as fp:
    json.dump(cycle_dict, fp)

# %%
for value in cycle_dict: 
    print(value)
# Out:
# asssulred
# dsro
# sulred
# SOX
# sulfur_ox
# sulfur_dis
# org_sul_trans
# in_or_sul
# sul_other

# %%
import numpy as np
import pandas as pd

metadata = pd.read_csv("../../cycdb_csv/metadata/metadata_filtered_scycdb.csv")

metadata["cycle"] = "nocycle"
metadata["cycle2"] = "nocycle"
metadata["cycle3"] = "nocycle"

metadata
# Out:
#                     id  gene database    cycle   cycle2   cycle3
# 0            385332883  acuI      COG  nocycle  nocycle  nocycle
# 1            162148265  acuI      COG  nocycle  nocycle  nocycle
# 2            217970029  acuI      COG  nocycle  nocycle  nocycle
# 3            288940713  acuI      COG  nocycle  nocycle  nocycle
# 4            384220944  acuI      COG  nocycle  nocycle  nocycle
# ...                ...   ...      ...      ...      ...      ...
# 529967  WP_117265927.1  dmsA     NCBI  nocycle  nocycle  nocycle
# 529968  WP_068006011.1  acuI     NCBI  nocycle  nocycle  nocycle
# 529969  WP_008111604.1  metC     NCBI  nocycle  nocycle  nocycle
# 529970  WP_070579647.1  cysJ     NCBI  nocycle  nocycle  nocycle
# 529971  WP_074972936.1  cysQ     NCBI  nocycle  nocycle  nocycle
#
# [529972 rows x 6 columns]

# %%
counter = 0

for value in cycle_dict: 
    for value2 in cycle_dict[value]: 
            metadata.loc[(metadata["gene"] == value2) & (metadata['cycle'] == "nocycle"), 'cycle'] = value
            metadata.loc[(metadata["gene"] == value2) & (metadata['cycle'] != value), 'cycle2'] = value
            metadata.loc[(metadata["gene"] == value2) & (metadata['cycle'] != value) & (metadata['cycle2'] != value), 'cycle3'] = value


    counter += 1
    print(counter)
print(metadata)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
#                     id  gene database          cycle   cycle2   cycle3
# 0            385332883  acuI      COG  org_sul_trans  nocycle  nocycle
# 1            162148265  acuI      COG  org_sul_trans  nocycle  nocycle
# 2            217970029  acuI      COG  org_sul_trans  nocycle  nocycle
# 3            288940713  acuI      COG  org_sul_trans  nocycle  nocycle
# 4            384220944  acuI      COG  org_sul_trans  nocycle  nocycle
# ...                ...   ...      ...            ...      ...      ...
# 529967  WP_117265927.1  dmsA     NCBI  org_sul_trans  nocycle  nocycle
# 529968  WP_068006011.1  acuI     NCBI  org_sul_trans  nocycle  nocycle
# 529969  WP_008111604.1  metC     NCBI      in_or_sul  nocycle  nocycle
# 529970  WP_070579647.1  cysJ     NCBI      asssulred  nocycle  nocycle
# 529971  WP_074972936.1  cysQ     NCBI      asssulred  nocycle  nocycle
#
# [529972 rows x 6 columns]

# %%
metadata
# Out:
#                     id  gene database          cycle   cycle2   cycle3
# 0            385332883  acuI      COG  org_sul_trans  nocycle  nocycle
# 1            162148265  acuI      COG  org_sul_trans  nocycle  nocycle
# 2            217970029  acuI      COG  org_sul_trans  nocycle  nocycle
# 3            288940713  acuI      COG  org_sul_trans  nocycle  nocycle
# 4            384220944  acuI      COG  org_sul_trans  nocycle  nocycle
# ...                ...   ...      ...            ...      ...      ...
# 529967  WP_117265927.1  dmsA     NCBI  org_sul_trans  nocycle  nocycle
# 529968  WP_068006011.1  acuI     NCBI  org_sul_trans  nocycle  nocycle
# 529969  WP_008111604.1  metC     NCBI      in_or_sul  nocycle  nocycle
# 529970  WP_070579647.1  cysJ     NCBI      asssulred  nocycle  nocycle
# 529971  WP_074972936.1  cysQ     NCBI      asssulred  nocycle  nocycle
#
# [529972 rows x 6 columns]

# %%
metadata.to_csv("../../cycdb_csv/metadata_with_pathways/grouped_metadata_multigroups_scycdb.csv")
